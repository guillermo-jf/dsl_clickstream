# %% [markdown]
# ## Task 2: Writing Dataflow batch pipelines
#
# In this task, you use Apache Beam and Dataflow to run a batch processing pipeline to accomplish the same job as in the previous task. Read the data from Cloud Storage, parse it, and write it to BigQuery using a schema that is optimized for analytics.
#
# Using Apache Beam, create a pipeline to migrate the clickstream data to BigQuery in accordance with the schema you created earlier. Program the pipeline in a Jupyter Notebook.
#
# Once you have the pipeline tested, run it using Google Cloud Dataflow.

# %%
pip install --upgrade apache-beam[gcp]
# Out:
# Requirement already satisfied: apache-beam[gcp] in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (2.65.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (3.10.18)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (0.3.1.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (1.10.0)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (1.65.5)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (4.23.0)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (3.4.2)
# Requirement already satisfied: numpy<2.3.0,>=1.14.3 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.2.5)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (0.7.1)
# Requirement already satisfied: packaging>=22.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (25.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (4.13.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (1.26.1)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<6.0.0.dev0,>=3.20.3 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (5.29.4)
# Requirement already satisfied: pydot<2,>=1.2.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.3 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2025.2)
# Requirement already satisfied: redis<6,>=5.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (5.3.0)
# Requirement already satisfied: regex>=2020.6.8 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2024.11.6)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.32.3)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (4.13.2)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (0.23.0)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (6.0.2)
# Requirement already satisfied: pyarrow<17.0.0,>=3.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (0.7)
# Requirement already satisfied: cachetools<6,>=3.1.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (5.5.2)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.24.2)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (0.5.31)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.40.1)
# Requirement already satisfied: google-auth-httplib2<0.3.0,>=0.1.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (0.2.0)
# Requirement already satisfied: google-cloud-datastore<3,>=2.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.21.0)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.29.0)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (1.12.0)
# Requirement already satisfied: google-cloud-storage<3,>=2.18.2 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery<4,>=2.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (3.32.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.6.3 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.31.0)
# Requirement already satisfied: google-cloud-core<3,>=2.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.4.3)
# Requirement already satisfied: google-cloud-bigtable<3,>=2.19.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.30.1)
# Requirement already satisfied: google-cloud-spanner<4,>=3.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (3.54.0)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (3.29.0)
# Requirement already satisfied: google-cloud-language<3,>=2.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.17.1)
# Requirement already satisfied: google-cloud-videointelligence<3,>=2.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (2.16.1)
# Requirement already satisfied: google-cloud-vision<4,>=2 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (3.10.1)
# Requirement already satisfied: google-cloud-recommendations-ai<0.11.0,>=0.1.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (0.10.17)
# Requirement already satisfied: google-cloud-aiplatform<2.0,>=1.26.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (1.93.0)
# Requirement already satisfied: keyrings.google-artifactregistry-auth in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from apache-beam[gcp]) (1.1.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-api-core<3,>=2.0.0->apache-beam[gcp]) (1.70.0)
# Requirement already satisfied: oauth2client>=1.4.12 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]) (4.1.3)
# Requirement already satisfied: six>=1.12.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]) (1.17.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]) (4.9.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (2.1.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (1.15.0)
# Requirement already satisfied: pydantic<3 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (2.11.4)
# Requirement already satisfied: docstring-parser<1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.16)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (1.65.5)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]) (1.7.1)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (1.33.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (1.33.0)
# Requirement already satisfied: overrides<8.0.0,>=6.0.1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]) (7.7.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]) (0.15.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (4.9.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.28.1)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (1.3.1)
# Requirement already satisfied: docopt in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from httplib2<0.23.0,>=0.8->apache-beam[gcp]) (3.2.3)
# Requirement already satisfied: certifi in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.4.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from pymongo<5.0.0,>=3.8.0->apache-beam[gcp]) (2.7.0)
# Requirement already satisfied: PyJWT~=2.9.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from redis<6,>=5.0.0->apache-beam[gcp]) (2.9.0)
# Requirement already satisfied: async-timeout>=4.0.3 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from redis<6,>=5.0.0->apache-beam[gcp]) (5.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]) (2.4.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.18.0->apache-beam[gcp]) (0.6.1)
# Requirement already satisfied: deprecated>=1.2.6 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (3.21.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (1.17.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (0.54b0)
# Requirement already satisfied: keyring in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]) (25.6.0)
# Requirement already satisfied: pluggy in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]) (1.6.0)
# Requirement already satisfied: SecretStorage>=3.2 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (3.3.3)
# Requirement already satisfied: jeepney>=0.4.2 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (0.9.0)
# Requirement already satisfied: jaraco.classes in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (3.4.0)
# Requirement already satisfied: jaraco.functools in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (4.1.0)
# Requirement already satisfied: jaraco.context in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (6.0.1)
# Requirement already satisfied: cryptography>=2.0 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from SecretStorage>=3.2->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (44.0.3)
# Requirement already satisfied: cffi>=1.12 in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (1.17.1)
# Requirement already satisfied: pycparser in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (2.22)
# Requirement already satisfied: more-itertools in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from jaraco.classes->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (10.7.0)
# Requirement already satisfied: backports.tarfile in /jupyter/.kernels/apache-beam-2.63.0/lib/python3.10/site-packages (from jaraco.context->keyring->keyrings.google-artifactregistry-auth->apache-beam[gcp]) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import IPython
from IPython.display import display

app = IPython.Application.instance()
app.kernel.do_shutdown(True)

# %%
import apache_beam as beam
from apache_beam.options.pipeline_options import PipelineOptions, GoogleCloudOptions
from google.cloud import bigquery
import json
import os
from datetime import datetime

# Set your Google Cloud project ID and dataset
PROJECT_ID = "jellyfish-training-demo-6"
DATASET_ID = "dsl_project"
TABLE_ID = "web_visits_batch"
TEMP_LOCATION = f"gs://{PROJECT_ID}/temp"
REGION = "us-central1"

# Create the unique job name by appending the timestamp
timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
JOB_NAME = f"storage-to-bq-{timestamp}"

# %%
# Initialize BigQuery client
client = bigquery.Client(project=PROJECT_ID)

# %%
# Specify your GCS JSONL file path
input_path = "gs://guillermo-lake/visits-*.jsonl"

# Define the BigQuery schema as a JSON object (not a plain string)
SCHEMA = {
    "fields": [
        {"name": "session_id", "type": "STRING"},
        {"name": "user_id", "type": "STRING"},
        {"name": "device_type", "type": "STRING"},
        {"name": "geolocation", "type": "STRING"},
        {"name": "user_agent", "type": "STRING"},
        {
            "name": "events",
            "type": "RECORD",
            "mode": "REPEATED",
            "fields": [
                {
                    "name": "event",
                    "type": "RECORD",
                    "fields": [
                        {"name": "event_type", "type": "STRING"},
                        {"name": "timestamp", "type": "TIMESTAMP"},
                        {
                            "name": "details",
                            "type": "RECORD",
                            "fields": [
                                {"name": "page_url", "type": "STRING"},
                                {"name": "referrer_url", "type": "STRING"},
                                {"name": "product_id", "type": "STRING"},
                                {"name": "product_name", "type": "STRING"},
                                {"name": "category", "type": "STRING"},
                                {"name": "price", "type": "FLOAT"},
                                {"name": "quantity", "type": "INTEGER"},
                                {"name": "order_id", "type": "STRING"},
                                {"name": "amount", "type": "FLOAT"},
                                {"name": "currency", "type": "STRING"},
                                {
                                    "name": "items",
                                    "type": "RECORD",
                                    "mode": "REPEATED",
                                    "fields": [
                                        {"name": "product_id", "type": "STRING"},
                                        {"name": "product_name", "type": "STRING"},
                                        {"name": "category", "type": "STRING"},
                                        {"name": "price", "type": "FLOAT"},
                                        {"name": "quantity", "type": "INTEGER"},
                                    ],
                                },
                            ],
                        },
                    ],
                }
            ],
        },
    ]
}

class ParseJsonlFn(beam.DoFn):
    def process(self, element):
        try:
            record = json.loads(element)
            yield record
        except Exception as e:
            print(f"Error parsing record: {e}")

# Initialize BigQuery client
client = bigquery.Client(project=PROJECT_ID)

def create_table():
    """Creates the BigQuery table if it does not exist."""
    dataset_ref = client.dataset(DATASET_ID)
    table_ref = dataset_ref.table(TABLE_ID)
    table = bigquery.Table(table_ref, schema=[bigquery.SchemaField.from_api_repr(field) for field in SCHEMA["fields"]])
    
    try:
        client.create_table(table)
        print(f"Table {TABLE_ID} created successfully.")
    except Exception as e:
        print(f"Table creation failed: {e}")

def run_pipeline(input_path):
    """Runs the Apache Beam pipeline to process JSONL files."""
    options = PipelineOptions(flags=[
        "--project", PROJECT_ID,
        "--runner", "DirectRunner",  # Runs locally
        "--temp_location", f"gs://{PROJECT_ID}/temp"
    ])

    with beam.Pipeline(options=options) as pipeline:
        (
            pipeline
            | "Read JSONL File" >> beam.io.ReadFromText(input_path)
            | "Parse JSON" >> beam.ParDo(ParseJsonlFn())
            | "Write to BigQuery" >> beam.io.WriteToBigQuery(
                table=f"{PROJECT_ID}:{DATASET_ID}.{TABLE_ID}",
                schema=SCHEMA,  # Pass the schema directly as a Python dictionary
                create_disposition=beam.io.BigQueryDisposition.CREATE_IF_NEEDED,
                write_disposition=beam.io.BigQueryDisposition.WRITE_TRUNCATE,
                custom_gcs_temp_location=f"gs://{PROJECT_ID}/temp"
            )
        )

# Run table creation
#create_table()

# %%
# Run the pipeline locally
run_pipeline(input_path)

# %%
# Define and run the pipeline options for dataflow

options = PipelineOptions()
google_cloud_options = options.view_as(GoogleCloudOptions)
google_cloud_options.project = PROJECT_ID
google_cloud_options.job_name = JOB_NAME
google_cloud_options.staging_location = f'gs://{PROJECT_ID}/staging'
google_cloud_options.temp_location = f'gs://{PROJECT_ID}/temp'
google_cloud_options.region = REGION  
options.view_as(beam.options.pipeline_options.StandardOptions).runner = 'DataflowRunner'


with beam.Pipeline(options=options) as pipeline:
        (
            pipeline
            | "Read JSONL File" >> beam.io.ReadFromText(input_path)
            | "Parse JSON" >> beam.ParDo(ParseJsonlFn())
            | "Write to BigQuery" >> beam.io.WriteToBigQuery(
                f"{PROJECT_ID}:{DATASET_ID}.{TABLE_ID}",
                schema=SCHEMA,  # Pass the schema directly as a Python dictionary
                create_disposition=beam.io.BigQueryDisposition.CREATE_IF_NEEDED,
                write_disposition=beam.io.BigQueryDisposition.WRITE_TRUNCATE,

            )
        )
