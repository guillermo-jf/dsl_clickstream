# %% [markdown]
# # Simulated Visit Generator
#
# The function below generates a simulated visit to a web site. A visit has a collection of events. There are 3 types of events: Page Views, Add Item to Cart, and Purchase.
#
# All events have page views. Some have Add to Cart events. Some of the visits with Add to Cart events have purchases.
#
# The OpenAPI schema for a Visit is shown below.
#
# ```
# openapi: 3.0.0
# info:
#   title: Visit Schema API
#   version: 1.0.0
#   description: Schema for representing a visit to a website, including page views, adding items to a cart, and purchases.
# paths: {}
# components:
#   schemas:
#     Visit:
#       type: object
#       properties:
#         session_id:
#           type: string
#           example: "SID-1234"
#           description: "A unique identifier for the user's session."
#         user_id:
#           type: string
#           example: "UID-5678"
#           description: "A unique identifier for the user visiting the website."
#         device_type:
#           type: string
#           enum: [desktop, mobile, tablet]
#           example: "desktop"
#           description: "The type of device used by the user."
#         geolocation:
#           type: string
#           example: "37.7749,-122.4194"
#           description: "The geolocation of the user in latitude,longitude format."
#         user_agent:
#           type: string
#           example: "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
#           description: "The user agent string of the browser/device used by the user."
#         events:
#           type: array
#           items:
#             $ref: '#/components/schemas/Event'
#           description: "List of events during the user's visit."
#
#     Event:
#       type: object
#       properties:
#         event_type:
#           type: string
#           enum: [page_view, add_item_to_cart, purchase]
#           example: "page_view"
#           description: "The type of event that occurred."
#         timestamp:
#           type: string
#           format: date-time
#           example: "2023-08-10T12:34:56Z"
#           description: "The exact time when the event occurred."
#         details:
#           type: object
#           oneOf:
#             - $ref: '#/components/schemas/PageViewDetails'
#             - $ref: '#/components/schemas/AddItemToCartDetails'
#             - $ref: '#/components/schemas/PurchaseDetails'
#           description: "Specific details of the event based on its type."
#
#     PageViewDetails:
#       type: object
#       properties:
#         page_url:
#           type: string
#           example: "https://example.com/products"
#           description: "The URL of the webpage that was viewed."
#         referrer_url:
#           type: string
#           nullable: true
#           example: "https://google.com"
#           description: "The URL of the referrer page that led to this page view, or null if none."
#
#     AddItemToCartDetails:
#       type: object
#       properties:
#         product_id:
#           type: string
#           example: "HDW-001"
#           description: "The unique identifier of the product added to the cart."
#         product_name:
#           type: string
#           example: "Laptop X200"
#           description: "The name of the product added to the cart."
#         category:
#           type: string
#           enum: [hardware, software, peripherals]
#           example: "hardware"
#           description: "The category of the product added to the cart."
#         price:
#           type: number
#           format: float
#           example: 999.99
#           description: "The price of the product added to the cart."
#         quantity:
#           type: integer
#           example: 2
#           description: "The quantity of the product added to the cart."
#
#     PurchaseDetails:
#       type: object
#       properties:
#         order_id:
#           type: string
#           example: "ORD-4321"
#           description: "A unique identifier for the order."
#         amount:
#           type: number
#           format: float
#           example: 1999.98
#           description: "The total amount of the purchase."
#         currency:
#           type: string
#           example: "USD"
#           description: "The currency used for the purchase."
#         items:
#           type: array
#           items:
#             $ref: '#/components/schemas/PurchaseItem'
#           description: "A list of items purchased in this order."
#
#     PurchaseItem:
#       type: object
#       properties:
#         product_id:
#           type: string
#           example: "HDW-001"
#           description: "The unique identifier of the product purchased."
#         product_name:
#           type: string
#           example: "Laptop X200"
#           description: "The name of the product purchased."
#         category:
#           type: string
#           enum: [hardware, software, peripherals]
#           example: "hardware"
#           description: "The category of the product purchased."
#         price:
#           type: number
#           format: float
#           example: 999.99
#           description: "The price of the product purchased."
#         quantity:
#           type: integer
#           example: 2
#           description: "The quantity of the product purchased."
#
# ```

# %%
import random
from datetime import datetime, timedelta
import json
import time
from datetime import date
import logging
from google.cloud import pubsub_v1

# %%
def generate_visit(custom_timestamp=None):
    # Sample products categorized by type with hard-coded product IDs and popularity scores
    products = {
        "hardware": [
            {"product_id": "HDW-001", "name": "Laptop X200", "price": 999.99, "popularity": 0.3},
            {"product_id": "HDW-002", "name": "Desktop Z500", "price": 1299.99, "popularity": 0.2},
            {"product_id": "HDW-003", "name": "Gaming PC Y900", "price": 1899.99, "popularity": 0.1},
            {"product_id": "HDW-004", "name": "Ultrabook A400", "price": 1199.99, "popularity": 0.15},
            {"product_id": "HDW-005", "name": "Workstation Pro 9000", "price": 2599.99, "popularity": 0.05},
            {"product_id": "HDW-006", "name": "Mini PC Cube", "price": 699.99, "popularity": 0.2}
        ],
        "software": [
            {"product_id": "SFT-001", "name": "Office Suite Pro", "price": 199.99, "popularity": 0.25},
            {"product_id": "SFT-002", "name": "Antivirus Shield", "price": 49.99, "popularity": 0.3},
            {"product_id": "SFT-003", "name": "Photo Editor Pro", "price": 79.99, "popularity": 0.15},
            {"product_id": "SFT-004", "name": "Project Manager Plus", "price": 299.99, "popularity": 0.1},
            {"product_id": "SFT-005", "name": "Video Editor Pro", "price": 149.99, "popularity": 0.1},
            {"product_id": "SFT-006", "name": "Music Studio 2024", "price": 89.99, "popularity": 0.1}
        ],
        "peripherals": [
            {"product_id": "PER-001", "name": "Wireless Mouse", "price": 29.99, "popularity": 0.4},
            {"product_id": "PER-002", "name": "Mechanical Keyboard", "price": 89.99, "popularity": 0.3},
            {"product_id": "PER-003", "name": "27\" 4K Monitor", "price": 399.99, "popularity": 0.1},
            {"product_id": "PER-004", "name": "USB-C Docking Station", "price": 129.99, "popularity": 0.05},
            {"product_id": "PER-005", "name": "Noise Cancelling Headphones", "price": 199.99, "popularity": 0.1},
            {"product_id": "PER-006", "name": "Webcam HD 1080p", "price": 49.99, "popularity": 0.05}
        ]
    }

    # Helper function to generate a timestamp
    def generate_timestamp():
        return custom_timestamp if custom_timestamp else datetime.now().isoformat()

    # Helper function to select a random product from a category based on popularity
    def select_random_product():
        category = random.choice(list(products.keys()))
        category_products = products[category]
        # Use weighted random choice based on popularity
        product = random.choices(category_products, weights=[p["popularity"] for p in category_products])[0]
        return product, category

    # Generating the base session details
    session = {
        "session_id": f"SID-{random.randint(1000, 9999)}",
        "user_id": f"UID-{random.randint(1000, 9999)}",
        "device_type": random.choices(
            ["mobile", "desktop", "tablet"], weights=[0.6, 0.3, 0.1]
        )[0],
        "geolocation": f"{random.uniform(-90, 90):.6f},{random.uniform(-180, 180):.6f}",
        "user_agent": random.choice([
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
            "Mozilla/5.0 (iPhone; CPU iPhone OS 14_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1",
            "Mozilla/5.0 (Linux; Android 10; SM-G973F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Mobile Safari/537.36"
        ]),
        "events": []
    }

    # The first page view is always the home page
    session["events"].append({
        "event": {
            "event_type": "page_view",
            "timestamp": generate_timestamp(),
            "details": {
                "page_url": "https://example.com/home",
                "referrer_url": None  # No referrer for the first page view
            }
        }
    })

    # The second page view is always the products page
    session["events"].append({
        "event": {
            "event_type": "page_view",
            "timestamp": generate_timestamp(),
            "details": {
                "page_url": "https://example.com/products",
                "referrer_url": "https://example.com/home"
            }
        }
    })

    # Adding between 0 and 4 additional page_view events with low probability for about and contact pages
    num_additional_page_views = random.randint(0, 4)
    for _ in range(num_additional_page_views):
        page_url = random.choices(
            [
                "https://example.com/cart",
                "https://example.com/about",
                "https://example.com/contact"
            ],
            [0.9, 0.05, 0.05]  # 90% chance of cart, 5% each for about and contact
        )[0]

        page_view_event = {
            "event": {
                "event_type": "page_view",
                "timestamp": generate_timestamp(),
                "details": {
                    "page_url": page_url,
                    "referrer_url": random.choice([
                        "https://google.com",
                        "https://example.com/home",
                        "https://example.com/products"
                    ])
                }
            }
        }
        session["events"].append(page_view_event)

    # Determine whether to add add_item_to_cart events
    added_items = []
    if random.random() < 0.5:  # 50% chance to add items to the cart
        num_items_to_add = random.randint(1, 3)
        for _ in range(num_items_to_add):
            product, category = select_random_product()
            add_item_to_cart_event = {
                "event": {
                    "event_type": "add_item_to_cart",
                    "timestamp": generate_timestamp(),
                    "details": {
                        "product_id": product["product_id"],
                        "product_name": product["name"],
                        "category": category,
                        "price": product["price"],
                        "quantity": random.randint(1, 5)
                    }
                }
            }
            session["events"].append(add_item_to_cart_event)
            added_items.append(add_item_to_cart_event)

    # Determine whether to add a purchase event
    if added_items and random.random() < 0.5:  # Only add purchase if items were added to cart
        total_amount = sum(
            item["event"]["details"]["price"] * item["event"]["details"]["quantity"]
            for item in added_items
        )
        purchase_event = {
            "event": {
                "event_type": "purchase",
                "timestamp": generate_timestamp(),
                "details": {
                    "order_id": f"ORD-{random.randint(1000, 9999)}",
                    "amount": total_amount,
                    "currency": "USD",
                    "items": [
                        {
                            "product_id": item["event"]["details"]["product_id"],
                            "product_name": item["event"]["details"]["product_name"],
                            "category": item["event"]["details"]["category"],
                            "price": item["event"]["details"]["price"],
                            "quantity": item["event"]["details"]["quantity"]
                        }
                        for item in added_items
                    ]
                }
            }
        }
        session["events"].append(purchase_event)

    return session

# Example usage
visit = generate_visit("2024-08-12T14:30:00")

visit_json = json.dumps(visit, indent=4)
print(visit_json)
# Out:
# {
#     "session_id": "SID-1801",
#     "user_id": "UID-2748",
#     "device_type": "mobile",
#     "geolocation": "0.476465,136.525967",
#     "user_agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 14_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1",
#     "events": [
#         {
#             "event": {
#                 "event_type": "page_view",
#                 "timestamp": "2024-08-12T14:30:00",
#                 "details": {
#                     "page_url": "https://example.com/home",
#                     "referrer_url": null
#                 }
#             }
#         },
#         {
#             "event": {
#                 "event_type": "page_view",
#                 "timestamp": "2024-08-12T14:30:00",
#                 "details": {
#                     "page_url": "https://example.com/products",
#                     "referrer_url": "https://example.com/home"
#                 }
#             }
#         },
#         {
#             "event": {
#                 "event_type": "page_view",
#                 "timestamp": "2024-08-12T14:30:00",
#                 "details": {
#                     "page_url": "https://example.com/cart",
#                     "referrer_url": "https://example.com/home"
#                 }
#             }
#         },
#         {
#             "event": {
#                 "event_type": "page_view",
#                 "timestamp": "2024-08-12T14:30:00",
#                 "details": {
#                     "page_url": "https://example.com/cart",
#                     "referrer_url": "https://example.com/home"
#                 }
#             }
#         },
#         {
#             "event": {
#                 "event_type": "page_view",
#                 "timestamp": "2024-08-12T14:30:00",
#                 "details": {
#                     "page_url": "https://example.com/cart",
#                     "referrer_url": "https://example.com/home"
#                 }
#             }
#         },
#         {
#             "event": {
#                 "event_type": "page_view",
#                 "timestamp": "2024-08-12T14:30:00",
#                 "details": {
#                     "page_url": "https://example.com/cart",
#                     "referrer_url": "https://google.com"
#                 }
#             }
#         }
#     ]
# }

# %% [markdown]
# # Generate messages with Sample Visits
#
# The function below publishes messages with new generated visits to a pubsub topic. Use parameters to define for how long (in minutes) and how many visits per minute are generated.

# %%
def run_visits_simulator(start_date, visits_per_minute, duration_minutes, project_id, topic_id):
    
    current_date = start_date
    delay_seconds = 60.0 / visits_per_minute
    start_time = time.time() 
    end_time = start_time + duration_minutes * 60
    #current_time = datetime.combine(current_date, datetime.min.time()) + timedelta(hours=9)
    
    #logging.info(f"Starting simulator for {args.duration_minutes} minute(s), generating {args.visits_per_minute} visits per minute...")
    #logging.info(f"Publishing to topic: {topic_path}")

    publisher = pubsub_v1.PublisherClient()
    topic_path = publisher.topic_path(project_id, topic_id)    
    
    try:
        while time.time() < end_time:
            current_time = datetime.now()
            custom_timestamp = current_time.isoformat()
            
            visit_to_publish = generate_visit(custom_timestamp)
            
            visit_json_data = json.dumps(visit_to_publish)
            visit_bytes_data = visit_json_data.encode("utf-8")
            
            # publish event to topic
            new_event = publisher.publish(topic_path, data=visit_bytes_data)
            
            # Consider adding a callback for more robust error handling if needed
            #logging.info(f"Published message ID: {future.result(timeout=10)} to topic {topic_path}")
            print(visit_to_publish)
            print('-')
            time.sleep(delay_seconds)
            
    except Exception as e:
        logging.error(f"An error occurred during simulation: {e}")
    finally:
        logging.info(f"Simulator finished after {duration_minutes} minute(s).")

# %%
# Example usage:

PROJECT_ID = "jellyfish-training-demo-6"
TOPIC_ID = "dsl-project-clickstream"
START_DATE = date.today()                  # Starting date
NUM_MIN = 5                                # Number of minutes
VISITS_PER_MINUTE = 5                      # number of visits per minute

#generate_visits_for_days(START_DATE, NUM_DAYS, VISITS_PER_DAY_RANGE, seed=SEED, time_increment_minutes=TIME_INCREMENT_MINUTES)

run_visits_simulator(START_DATE, VISITS_PER_MINUTE,NUM_MIN, PROJECT_ID, TOPIC_ID)

print("Done")
# Out:
# {'session_id': 'SID-9726', 'user_id': 'UID-9400', 'device_type': 'desktop', 'geolocation': '-74.192883,16.825079', 'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:13.212376', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:13.212376', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:13.212376', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:39:13.212376', 'details': {'product_id': 'PER-003', 'product_name': '27" 4K Monitor', 'category': 'peripherals', 'price': 399.99, 'quantity': 4}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:39:13.212376', 'details': {'product_id': 'HDW-004', 'product_name': 'Ultrabook A400', 'category': 'hardware', 'price': 1199.99, 'quantity': 3}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:39:13.212376', 'details': {'product_id': 'PER-004', 'product_name': 'USB-C Docking Station', 'category': 'peripherals', 'price': 129.99, 'quantity': 3}}}, {'event': {'event_type': 'purchase', 'timestamp': '2025-06-19T20:39:13.212376', 'details': {'order_id': 'ORD-1654', 'amount': 5589.900000000001, 'currency': 'USD', 'items': [{'product_id': 'PER-003', 'product_name': '27" 4K Monitor', 'category': 'peripherals', 'price': 399.99, 'quantity': 4}, {'product_id': 'HDW-004', 'product_name': 'Ultrabook A400', 'category': 'hardware', 'price': 1199.99, 'quantity': 3}, {'product_id': 'PER-004', 'product_name': 'USB-C Docking Station', 'category': 'peripherals', 'price': 129.99, 'quantity': 3}]}}}]}
# -
# {'session_id': 'SID-5514', 'user_id': 'UID-9364', 'device_type': 'desktop', 'geolocation': '11.651190,134.264269', 'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 14_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:25.214612', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:25.214612', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:25.214612', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:25.214612', 'details': {'page_url': 'https://example.com/about', 'referrer_url': 'https://example.com/products'}}}]}
# -
# {'session_id': 'SID-4541', 'user_id': 'UID-5607', 'device_type': 'desktop', 'geolocation': '-71.695632,-81.926860', 'user_agent': 'Mozilla/5.0 (Linux; Android 10; SM-G973F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Mobile Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:37.227585', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:37.227585', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:37.227585', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:37.227585', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:37.227585', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}]}
# -
# {'session_id': 'SID-8809', 'user_id': 'UID-1598', 'device_type': 'desktop', 'geolocation': '80.877695,125.681557', 'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:49.239599', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:39:49.239599', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:39:49.239599', 'details': {'product_id': 'SFT-001', 'product_name': 'Office Suite Pro', 'category': 'software', 'price': 199.99, 'quantity': 5}}}]}
# -
# {'session_id': 'SID-2816', 'user_id': 'UID-2904', 'device_type': 'mobile', 'geolocation': '21.501731,-124.042029', 'user_agent': 'Mozilla/5.0 (Linux; Android 10; SM-G973F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Mobile Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:01.246647', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:01.246647', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:01.246647', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:01.246647', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:40:01.246647', 'details': {'product_id': 'SFT-002', 'product_name': 'Antivirus Shield', 'category': 'software', 'price': 49.99, 'quantity': 5}}}, {'event': {'event_type': 'purchase', 'timestamp': '2025-06-19T20:40:01.246647', 'details': {'order_id': 'ORD-4893', 'amount': 249.95000000000002, 'currency': 'USD', 'items': [{'product_id': 'SFT-002', 'product_name': 'Antivirus Shield', 'category': 'software', 'price': 49.99, 'quantity': 5}]}}}]}
# -
# {'session_id': 'SID-2750', 'user_id': 'UID-8961', 'device_type': 'tablet', 'geolocation': '-72.648144,-167.563668', 'user_agent': 'Mozilla/5.0 (Linux; Android 10; SM-G973F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Mobile Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:13.259589', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:13.259589', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:13.259589', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:40:13.259589', 'details': {'product_id': 'HDW-003', 'product_name': 'Gaming PC Y900', 'category': 'hardware', 'price': 1899.99, 'quantity': 4}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:40:13.259589', 'details': {'product_id': 'HDW-004', 'product_name': 'Ultrabook A400', 'category': 'hardware', 'price': 1199.99, 'quantity': 5}}}]}
# -
# {'session_id': 'SID-3016', 'user_id': 'UID-5236', 'device_type': 'desktop', 'geolocation': '-84.468242,155.690511', 'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 14_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:25.261620', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:25.261620', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:25.261620', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:40:25.261620', 'details': {'product_id': 'SFT-001', 'product_name': 'Office Suite Pro', 'category': 'software', 'price': 199.99, 'quantity': 1}}}]}
# -
# {'session_id': 'SID-7069', 'user_id': 'UID-7740', 'device_type': 'mobile', 'geolocation': '26.346916,113.362011', 'user_agent': 'Mozilla/5.0 (Linux; Android 10; SM-G973F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Mobile Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:37.268482', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:37.268482', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:37.268482', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:37.268482', 'details': {'page_url': 'https://example.com/contact', 'referrer_url': 'https://example.com/products'}}}]}
# -
# {'session_id': 'SID-2562', 'user_id': 'UID-3298', 'device_type': 'mobile', 'geolocation': '81.124797,66.530466', 'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:49.280633', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:49.280633', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:49.280633', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:49.280633', 'details': {'page_url': 'https://example.com/about', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:40:49.280633', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}]}
# -
# {'session_id': 'SID-3186', 'user_id': 'UID-7607', 'device_type': 'desktop', 'geolocation': '29.389594,-168.534236', 'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 14_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:01.287685', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:01.287685', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:01.287685', 'details': {'page_url': 'https://example.com/about', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:01.287685', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:01.287685', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}]}
# -
# {'session_id': 'SID-8607', 'user_id': 'UID-2483', 'device_type': 'desktop', 'geolocation': '-67.639218,-40.547102', 'user_agent': 'Mozilla/5.0 (Linux; Android 10; SM-G973F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Mobile Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:13.299607', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:13.299607', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:13.299607', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:13.299607', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:13.299607', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}]}
# -
# {'session_id': 'SID-7314', 'user_id': 'UID-9347', 'device_type': 'mobile', 'geolocation': '-42.126686,89.187914', 'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 14_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:25.312416', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:25.312416', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:25.312416', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}]}
# -
# {'session_id': 'SID-9156', 'user_id': 'UID-2262', 'device_type': 'mobile', 'geolocation': '36.392505,-10.364827', 'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:37.324595', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:37.324595', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:37.324595', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}]}
# -
# {'session_id': 'SID-4320', 'user_id': 'UID-9775', 'device_type': 'desktop', 'geolocation': '77.958402,-33.424162', 'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 14_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:49.337467', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:49.337467', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:49.337467', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:49.337467', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:49.337467', 'details': {'page_url': 'https://example.com/about', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:41:49.337467', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:41:49.337467', 'details': {'product_id': 'HDW-001', 'product_name': 'Laptop X200', 'category': 'hardware', 'price': 999.99, 'quantity': 4}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:41:49.337467', 'details': {'product_id': 'SFT-006', 'product_name': 'Music Studio 2024', 'category': 'software', 'price': 89.99, 'quantity': 1}}}]}
# -
# {'session_id': 'SID-2792', 'user_id': 'UID-5201', 'device_type': 'mobile', 'geolocation': '44.076031,179.551189', 'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:01.350360', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:01.350360', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:01.350360', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:01.350360', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:42:01.350360', 'details': {'product_id': 'HDW-003', 'product_name': 'Gaming PC Y900', 'category': 'hardware', 'price': 1899.99, 'quantity': 4}}}]}
# -
# {'session_id': 'SID-3106', 'user_id': 'UID-8676', 'device_type': 'mobile', 'geolocation': '-42.399117,11.668901', 'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 14_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:13.354639', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:13.354639', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}]}
# -
# {'session_id': 'SID-1743', 'user_id': 'UID-3413', 'device_type': 'tablet', 'geolocation': '21.464529,-48.401371', 'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 14_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:25.366909', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:25.366909', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:25.366909', 'details': {'page_url': 'https://example.com/about', 'referrer_url': 'https://example.com/products'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:42:25.366909', 'details': {'product_id': 'PER-001', 'product_name': 'Wireless Mouse', 'category': 'peripherals', 'price': 29.99, 'quantity': 5}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:42:25.366909', 'details': {'product_id': 'PER-005', 'product_name': 'Noise Cancelling Headphones', 'category': 'peripherals', 'price': 199.99, 'quantity': 1}}}, {'event': {'event_type': 'purchase', 'timestamp': '2025-06-19T20:42:25.366909', 'details': {'order_id': 'ORD-6936', 'amount': 349.94, 'currency': 'USD', 'items': [{'product_id': 'PER-001', 'product_name': 'Wireless Mouse', 'category': 'peripherals', 'price': 29.99, 'quantity': 5}, {'product_id': 'PER-005', 'product_name': 'Noise Cancelling Headphones', 'category': 'peripherals', 'price': 199.99, 'quantity': 1}]}}}]}
# -
# {'session_id': 'SID-3504', 'user_id': 'UID-7570', 'device_type': 'desktop', 'geolocation': '-45.238756,166.165312', 'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 14_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:37.380052', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:37.380052', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:37.380052', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:37.380052', 'details': {'page_url': 'https://example.com/contact', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:42:37.380052', 'details': {'product_id': 'PER-002', 'product_name': 'Mechanical Keyboard', 'category': 'peripherals', 'price': 89.99, 'quantity': 2}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:42:37.380052', 'details': {'product_id': 'SFT-001', 'product_name': 'Office Suite Pro', 'category': 'software', 'price': 199.99, 'quantity': 5}}}]}
# -
# {'session_id': 'SID-1900', 'user_id': 'UID-1039', 'device_type': 'tablet', 'geolocation': '72.425113,162.170168', 'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:49.393037', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:49.393037', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:49.393037', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:49.393037', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:42:49.393037', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:42:49.393037', 'details': {'product_id': 'PER-001', 'product_name': 'Wireless Mouse', 'category': 'peripherals', 'price': 29.99, 'quantity': 1}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:42:49.393037', 'details': {'product_id': 'PER-001', 'product_name': 'Wireless Mouse', 'category': 'peripherals', 'price': 29.99, 'quantity': 4}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:42:49.393037', 'details': {'product_id': 'SFT-006', 'product_name': 'Music Studio 2024', 'category': 'software', 'price': 89.99, 'quantity': 2}}}]}
# -
# {'session_id': 'SID-2545', 'user_id': 'UID-4504', 'device_type': 'mobile', 'geolocation': '20.958912,-15.112591', 'user_agent': 'Mozilla/5.0 (Linux; Android 10; SM-G973F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Mobile Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:01.405953', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:01.405953', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:01.405953', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:01.405953', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:43:01.405953', 'details': {'product_id': 'PER-001', 'product_name': 'Wireless Mouse', 'category': 'peripherals', 'price': 29.99, 'quantity': 2}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:43:01.405953', 'details': {'product_id': 'PER-001', 'product_name': 'Wireless Mouse', 'category': 'peripherals', 'price': 29.99, 'quantity': 5}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:43:01.405953', 'details': {'product_id': 'PER-002', 'product_name': 'Mechanical Keyboard', 'category': 'peripherals', 'price': 89.99, 'quantity': 1}}}]}
# -
# {'session_id': 'SID-3145', 'user_id': 'UID-2804', 'device_type': 'mobile', 'geolocation': '-43.545665,7.594563', 'user_agent': 'Mozilla/5.0 (Linux; Android 10; SM-G973F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Mobile Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:13.418610', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:13.418610', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:13.418610', 'details': {'page_url': 'https://example.com/about', 'referrer_url': 'https://example.com/products'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:13.418610', 'details': {'page_url': 'https://example.com/about', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:13.418610', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:43:13.418610', 'details': {'product_id': 'SFT-002', 'product_name': 'Antivirus Shield', 'category': 'software', 'price': 49.99, 'quantity': 5}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:43:13.418610', 'details': {'product_id': 'PER-002', 'product_name': 'Mechanical Keyboard', 'category': 'peripherals', 'price': 89.99, 'quantity': 3}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:43:13.418610', 'details': {'product_id': 'HDW-001', 'product_name': 'Laptop X200', 'category': 'hardware', 'price': 999.99, 'quantity': 3}}}, {'event': {'event_type': 'purchase', 'timestamp': '2025-06-19T20:43:13.418610', 'details': {'order_id': 'ORD-4714', 'amount': 3519.8900000000003, 'currency': 'USD', 'items': [{'product_id': 'SFT-002', 'product_name': 'Antivirus Shield', 'category': 'software', 'price': 49.99, 'quantity': 5}, {'product_id': 'PER-002', 'product_name': 'Mechanical Keyboard', 'category': 'peripherals', 'price': 89.99, 'quantity': 3}, {'product_id': 'HDW-001', 'product_name': 'Laptop X200', 'category': 'hardware', 'price': 999.99, 'quantity': 3}]}}}]}
# -
# {'session_id': 'SID-3427', 'user_id': 'UID-7366', 'device_type': 'mobile', 'geolocation': '15.473838,90.934703', 'user_agent': 'Mozilla/5.0 (Linux; Android 10; SM-G973F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Mobile Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:25.431683', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:25.431683', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}]}
# -
# {'session_id': 'SID-5538', 'user_id': 'UID-6240', 'device_type': 'mobile', 'geolocation': '-9.504992,-55.035462', 'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 14_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:37.444479', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:37.444479', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:37.444479', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:37.444479', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:37.444479', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:43:37.444479', 'details': {'product_id': 'SFT-006', 'product_name': 'Music Studio 2024', 'category': 'software', 'price': 89.99, 'quantity': 5}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:43:37.444479', 'details': {'product_id': 'PER-001', 'product_name': 'Wireless Mouse', 'category': 'peripherals', 'price': 29.99, 'quantity': 5}}}, {'event': {'event_type': 'purchase', 'timestamp': '2025-06-19T20:43:37.444479', 'details': {'order_id': 'ORD-6508', 'amount': 599.9, 'currency': 'USD', 'items': [{'product_id': 'SFT-006', 'product_name': 'Music Studio 2024', 'category': 'software', 'price': 89.99, 'quantity': 5}, {'product_id': 'PER-001', 'product_name': 'Wireless Mouse', 'category': 'peripherals', 'price': 29.99, 'quantity': 5}]}}}]}
# -
# {'session_id': 'SID-2752', 'user_id': 'UID-1811', 'device_type': 'desktop', 'geolocation': '18.372054,172.249498', 'user_agent': 'Mozilla/5.0 (Linux; Android 10; SM-G973F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Mobile Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:49.456871', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:49.456871', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:49.456871', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://google.com'}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:43:49.456871', 'details': {'page_url': 'https://example.com/cart', 'referrer_url': 'https://example.com/products'}}}]}
# -
# {'session_id': 'SID-1094', 'user_id': 'UID-9042', 'device_type': 'desktop', 'geolocation': '18.479521,103.375597', 'user_agent': 'Mozilla/5.0 (Linux; Android 10; SM-G973F) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Mobile Safari/537.36', 'events': [{'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:44:01.467820', 'details': {'page_url': 'https://example.com/home', 'referrer_url': None}}}, {'event': {'event_type': 'page_view', 'timestamp': '2025-06-19T20:44:01.467820', 'details': {'page_url': 'https://example.com/products', 'referrer_url': 'https://example.com/home'}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:44:01.467820', 'details': {'product_id': 'PER-002', 'product_name': 'Mechanical Keyboard', 'category': 'peripherals', 'price': 89.99, 'quantity': 3}}}, {'event': {'event_type': 'add_item_to_cart', 'timestamp': '2025-06-19T20:44:01.467820', 'details': {'product_id': 'SFT-006', 'product_name': 'Music Studio 2024', 'category': 'software', 'price': 89.99, 'quantity': 2}}}]}
# -
# Done

# %%
def generate_timestamp():
    return custom_timestamp if custom_timestamp else datetime.now().isoformat()
    
generate_timestamp()
